# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.43.0 to work with Ali_workspace_student

# %% [markdown]
# ## Prepare data

# %%
from azureml.core import Dataset
from azureml.data.datapath import DataPath

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    Dataset.File.upload_directory(src_dir='data',
                              target=DataPath(default_ds, 'diabetes-data/')
                              )

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %%
for ds in ws.datasets:
    print(ds)
# Out:
# diabetes file dataset
# diabetes dataset

# %% [markdown]
# ## Create scripts for pipeline steps

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Writing diabetes_pipeline/prep_diabetes.py

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-data", type=str, dest='training_data', help='training data')
args = parser.parse_args()
training_data = args.training_data

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_data,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "anabavib1"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %%
# %%writefile $experiment_folder/experiment_env.yml
# name: experiment_env
# dependencies:
# - python=3.6.2
# - scikit-learn
# - ipykernel
# - matplotlib
# - pandas
# - pip
# - pip:
#   - azureml-defaults
#   - pyarrow
# Out:
# Writing diabetes_pipeline/experiment_env.yml

# %% [markdown]
# Now that you have a Conda configuration file, you can create an environment and use it in the run configuration for the pipeline.

# %%
from azureml.core import Environment
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment (from a .yml file)
experiment_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/experiment_env.yml")

# Register the environment 
experiment_env.register(workspace=ws)
registered_env = Environment.get(ws, 'experiment_env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline

# %%
from azureml.data import OutputFileDatasetConfig
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create an OutputFileDatasetConfig (temporary Data Reference) for data passed from step 1 to step 2
prepped_data = OutputFileDatasetConfig("prepped_data")

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-data', prepped_data.as_input()],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [b21732f6][2bc014f2-0901-4696-8717-8a7a05bb0701], (This step will run and generate new outputs)Created step Train and Register Model [a380ff1b][ed859403-2df6-4752-a5b8-41e724209469], (This step will run and generate new outputs)
#
# Submitted PipelineRun 28e74074-91be-47db-9db1-8be0cd9b2e83
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/28e74074-91be-47db-9db1-8be0cd9b2e83?wsid=/subscriptions/1b822ee6-a558-4a5d-8ad7-7af385162a03/resourcegroups/Ali_Student_Workspace/workspaces/Ali_workspace_student&tid=41f88ecb-ca63-404d-97dd-ab0a169fd138
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 28e74074-91be-47db-9db1-8be0cd9b2e83
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/28e74074-91be-47db-9db1-8be0cd9b2e83?wsid=/subscriptions/1b822ee6-a558-4a5d-8ad7-7af385162a03/resourcegroups/Ali_Student_Workspace/workspaces/Ali_workspace_student&tid=41f88ecb-ca63-404d-97dd-ab0a169fd138
# PipelineRun Status: Running
#
#
# StepRunId: fb15e589-1b05-4b50-bab3-86b96887b60e
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/fb15e589-1b05-4b50-bab3-86b96887b60e?wsid=/subscriptions/1b822ee6-a558-4a5d-8ad7-7af385162a03/resourcegroups/Ali_Student_Workspace/workspaces/Ali_workspace_student&tid=41f88ecb-ca63-404d-97dd-ab0a169fd138
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/07/21 22:47:28 Downloading source code...
# 2022/07/21 22:47:29 Finished downloading source code
# 2022/07/21 22:47:29 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/07/21 22:47:30 Successfully set up Docker network: acb_default_network
# 2022/07/21 22:47:30 Setting up Docker configuration...
# 2022/07/21 22:47:30 Successfully set up Docker configuration
# 2022/07/21 22:47:30 Logging in to registry: 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io
# 2022/07/21 22:47:31 Successfully logged into 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io
# 2022/07/21 22:47:31 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/07/21 22:47:31 Scanning for dependencies...
# 2022/07/21 22:47:31 Successfully scanned dependencies
# 2022/07/21 22:47:31 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220616.v1@sha256:2e18aafa005c25d3e0200d9dd39255ef5a30680a569cd1c3326fd65f5989db47
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220616.v1@sha256:2e18aafa005c25d3e0200d9dd39255ef5a30680a569cd1c3326fd65f5989db47: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# d7bfe07ed847: Pulling fs layer
# dcef2ac699a5: Pulling fs layer
# 42794fc92dfd: Pulling fs layer
# 88af38890981: Pulling fs layer
# 13e568c28e4b: Pulling fs layer
# 18f510a7158e: Pulling fs layer
# 8699f484c7da: Pulling fs layer
# a7071d489c78: Pulling fs layer
# fd21b2f1d9b3: Pulling fs layer
# fe7fa5ee3450: Pulling fs layer
# 18f510a7158e: Waiting
# 8699f484c7da: Waiting
# a7071d489c78: Waiting
# fd21b2f1d9b3: Waiting
# fe7fa5ee3450: Waiting
# 88af38890981: Waiting
# 13e568c28e4b: Waiting
# dcef2ac699a5: Verifying Checksum
# dcef2ac699a5: Download complete
# 88af38890981: Verifying Checksum
# 88af38890981: Download complete
# d7bfe07ed847: Verifying Checksum
# d7bfe07ed847: Download complete
# 42794fc92dfd: Verifying Checksum
# 42794fc92dfd: Download complete
# 13e568c28e4b: Verifying Checksum
# 13e568c28e4b: Download complete
# 8699f484c7da: Verifying Checksum
# 8699f484c7da: Download complete
# a7071d489c78: Verifying Checksum
# a7071d489c78: Download complete
# fd21b2f1d9b3: Verifying Checksum
# fd21b2f1d9b3: Download complete
# fe7fa5ee3450: Verifying Checksum
# fe7fa5ee3450: Download complete
# 18f510a7158e: Verifying Checksum
# 18f510a7158e: Download complete
# d7bfe07ed847: Pull complete
# dcef2ac699a5: Pull complete
# 42794fc92dfd: Pull complete
# 88af38890981: Pull complete
# 13e568c28e4b: Pull complete
# 18f510a7158e: Pull complete
# 8699f484c7da: Pull complete
# a7071d489c78: Pull complete
# fd21b2f1d9b3: Pull complete
# fe7fa5ee3450: Pull complete
# Digest: sha256:2e18aafa005c25d3e0200d9dd39255ef5a30680a569cd1c3326fd65f5989db47
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220616.v1@sha256:2e18aafa005c25d3e0200d9dd39255ef5a30680a569cd1c3326fd65f5989db47
#  ---> 14dd8bce8bd3
# Step 2/21 : USER root
#  ---> Running in 5f65d98108f0
# Removing intermediate container 5f65d98108f0
#  ---> 66ca79fbf905
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in d1d94f9432ff
# Removing intermediate container d1d94f9432ff
#  ---> edc16d94fe8b
# Step 4/21 : WORKDIR /
#  ---> Running in 27e382fb3c4b
# Removing intermediate container 27e382fb3c4b
#  ---> 1b11965f1e4b
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> c376a7aabb26
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 1d4643f9dbfa
# Removing intermediate container 1d4643f9dbfa
#  ---> adf119c61c8b
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> b11d2674ccfa
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 5269bf3ea35e
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | #3         |  14%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# dbus-1.13.18         | 504 KB    |            |   0%
# dbus-1.13.18         | 504 KB    | ########## | 100%
#
# pyqt-5.9.2           | 4.5 MB    |            |   0%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
#
# ipython-7.16.1       | 999 KB    |            |   0%
# ipython-7.16.1       | 999 KB    | ########## | 100%
# ipython-7.16.1       | 999 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# tk-8.6.12            | 3.0 MB    |            |   0%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
#
# icu-58.2             | 10.5 MB   |            |   0%
# icu-58.2             | 10.5 MB   | #######9   |  79%
# icu-58.2             | 10.5 MB   | ########## | 100%
#
# parso-0.8.3          | 70 KB     |            |   0%
# parso-0.8.3          | 70 KB     | ########## | 100%
#
# libpng-1.6.37        | 278 KB    |            |   0%
# libpng-1.6.37        | 278 KB    | ########## | 100%
#
# jedi-0.17.0          | 780 KB    |            |   0%
# jedi-0.17.0          | 780 KB    | ########## | 100%
# jedi-0.17.0          | 780 KB    | ########## | 100%
#
# intel-openmp-2022.0. | 4.2 MB    |            |   0%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# libxml2-2.9.14       | 718 KB    |            |   0%
# libxml2-2.9.14       | 718 KB    | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# nest-asyncio-1.5.1   | 10 KB     |            |   0%
# nest-asyncio-1.5.1   | 10 KB     | ########## | 100%
#
# zeromq-4.3.4         | 331 KB    |            |   0%
# zeromq-4.3.4         | 331 KB    | ########## | 100%
#
# ptyprocess-0.7.0     | 17 KB     |            |   0%
# ptyprocess-0.7.0     | 17 KB     | ########## | 100%
#
# lz4-c-1.9.3          | 185 KB    |            |   0%
# lz4-c-1.9.3          | 185 KB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# zstd-1.5.2           | 488 KB    |            |   0%
# zstd-1.5.2           | 488 KB    | ########## | 100%
#
# decorator-5.1.1      | 12 KB     |            |   0%
# decorator-5.1.1      | 12 KB     | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# freetype-2.11.0      | 618 KB    |            |   0%
# freetype-2.11.0      | 618 KB    | ########## | 100%
#
# python-dateutil-2.8. | 233 KB    |            |   0%
# python-dateutil-2.8. | 233 KB    | ########## | 100%
#
# libtiff-4.2.0        | 452 KB    |            |   0%
# libtiff-4.2.0        | 452 KB    | ########## | 100%
#
# pillow-8.3.1         | 637 KB    |            |   0%
# pillow-8.3.1         | 637 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# libxcb-1.15          | 505 KB    |            |   0%
# libxcb-1.15          | 505 KB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# glib-2.63.1          | 2.9 MB    |            |   0%
# glib-2.63.1          | 2.9 MB    | #########2 |  93%
# glib-2.63.1          | 2.9 MB    | ########## | 100%
#
# tornado-6.1          | 581 KB    |            |   0%
# tornado-6.1          | 581 KB    | ########## | 100%
#
# matplotlib-3.3.4     | 26 KB     |            |   0%
# matplotlib-3.3.4     | 26 KB     | ########## | 100%
#
# jupyter_client-7.1.2 | 93 KB     |            |   0%
# jupyter_client-7.1.2 | 93 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 4.8 MB    |            |   0%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
#
# libgcc-ng-11.2.0     | 5.3 MB    |            |   0%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# lcms2-2.12           | 312 KB    |            |   0%
# lcms2-2.12           | 312 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 8          |   9%
# mkl-2020.2           | 138.3 MB  | #9         |  19%
# mkl-2020.2           | 138.3 MB  | ###        |  30%
# mkl-2020.2           | 138.3 MB  | ####       |  41%
# mkl-2020.2           | 138.3 MB  | #####1     |  51%
# mkl-2020.2           | 138.3 MB  | ######1    |  62%
# mkl-2020.2           | 138.3 MB  | #######2   |  72%
# mkl-2020.2           | 138.3 MB  | ########2  |  83%
# mkl-2020.2           | 138.3 MB  | #########4 |  94%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
# qt-5.9.6             | 67.3 MB   |            |   0%
# qt-5.9.6             | 67.3 MB   | #2         |  12%
# qt-5.9.6             | 67.3 MB   | ###4       |  35%
# qt-5.9.6             | 67.3 MB   | #####6     |  57%
# qt-5.9.6             | 67.3 MB   | #######8   |  78%
# qt-5.9.6             | 67.3 MB   | ########## | 100%
# qt-5.9.6             | 67.3 MB   | ########## | 100%
#
# pcre-8.45            | 207 KB    |            |   0%
# pcre-8.45            | 207 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 27 KB     |            |   0%
# ipython_genutils-0.2 | 27 KB     | ########## | 100%
#
# ipykernel-5.3.4      | 181 KB    |            |   0%
# ipykernel-5.3.4      | 181 KB    | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# _openmp_mutex-5.1    | 21 KB     |            |   0%
# _openmp_mutex-5.1    | 21 KB     | ########## | 100%
#
# libwebp-base-1.2.2   | 440 KB    |            |   0%
# libwebp-base-1.2.2   | 440 KB    | ########## | 100%
#
# openjpeg-2.4.0       | 331 KB    |            |   0%
# openjpeg-2.4.0       | 331 KB    | ########## | 100%
#
# pexpect-4.8.0        | 53 KB     |            |   0%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# jupyter_core-4.8.1   | 74 KB     |            |   0%
# jupyter_core-4.8.1   | 74 KB     | ########## | 100%
#
# pyzmq-22.2.1         | 454 KB    |            |   0%
# pyzmq-22.2.1         | 454 KB    | ########## | 100%
#
# ca-certificates-2022 | 124 KB    |            |   0%
# ca-certificates-2022 | 124 KB    | ########## | 100%
#
# prompt-toolkit-3.0.2 | 259 KB    |            |   0%
# prompt-toolkit-3.0.2 | 259 KB    | ########## | 100%
#
# entrypoints-0.3      | 12 KB     |            |   0%
# entrypoints-0.3      | 12 KB     | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    |            |   0%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
#
# kiwisolver-1.3.1     | 86 KB     |            |   0%
# kiwisolver-1.3.1     | 86 KB     | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# xz-5.2.5             | 339 KB    |            |   0%
# xz-5.2.5             | 339 KB    | ########## | 100%
#
# pygments-2.11.2      | 759 KB    |            |   0%
# pygments-2.11.2      | 759 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# libuuid-1.0.3        | 17 KB     |            |   0%
# libuuid-1.0.3        | 17 KB     | ########## | 100%
#
# cycler-0.11.0        | 12 KB     |            |   0%
# cycler-0.11.0        | 12 KB     | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# jpeg-9e              | 240 KB    |            |   0%
# jpeg-9e              | 240 KB    | ########## | 100%
#
# pytz-2021.3          | 171 KB    |            |   0%
# pytz-2021.3          | 171 KB    | ########## | 100%
#
# backcall-0.2.0       | 13 KB     |            |   0%
# backcall-0.2.0       | 13 KB     | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# zlib-1.2.12          | 106 KB    |            |   0%
# zlib-1.2.12          | 106 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ###5       |  35%
# python-3.6.2         | 23.6 MB   | #######4   |  75%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# pandas-1.1.5         | 8.2 MB    |            |   0%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
#
# expat-2.4.4          | 169 KB    |            |   0%
# expat-2.4.4          | 169 KB    | ########## | 100%
#
# pyparsing-3.0.4      | 81 KB     |            |   0%
# pyparsing-3.0.4      | 81 KB     | ########## | 100%
#
# sip-4.19.8           | 274 KB    |            |   0%
# sip-4.19.8           | 274 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.1 MB    |            |   0%
# gstreamer-1.14.0     | 3.1 MB    | ########## | 100%
#
# libsodium-1.0.18     | 244 KB    |            |   0%
# libsodium-1.0.18     | 244 KB    | ########## | 100%
#
# traitlets-4.3.3      | 138 KB    |            |   0%
# traitlets-4.3.3      | 138 KB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# libgomp-11.2.0       | 474 KB    |            |   0%
# libgomp-11.2.0       | 474 KB    | ########## | 100%
#
# fontconfig-2.13.1    | 250 KB    |            |   0%
# fontconfig-2.13.1    | 250 KB    | ########## | 100%
#
# wcwidth-0.2.5        | 26 KB     |            |   0%
# wcwidth-0.2.5        | 26 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.43.0-py3-none-any.whl (2.0 kB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.43.0
#   Downloading azureml_dataset_runtime-1.43.0.post2-py3-none-any.whl (2.3 kB)
# Collecting azureml-core~=1.43.0
#   Downloading azureml_core-1.43.0-py3-none-any.whl (2.7 MB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.13-py3-none-any.whl (39 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Requirement already satisfied: numpy>=1.16.6 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from pyarrow->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 2)) (1.19.2)
# Collecting msrest<0.7.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.18.0-py2.py3-none-any.whl (82 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.43.0->azureml-defaults->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 1)) (2021.3)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.0.0-py3-none-any.whl (1.2 MB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
# Collecting azure-mgmt-core<=1.3.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.43.0->azureml-defaults->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 1)) (2.8.2)
# Collecting azure-mgmt-storage<=20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<38.0.0
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
# Collecting jmespath<=1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting urllib3<=1.26.9,>=1.23
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting azure-mgmt-resource<22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.0.0-py3-none-any.whl (489 kB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.24.2-py3-none-any.whl (178 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.2-py3-none-any.whl (15 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azure-core<2.0.0->azureml-core~=1.43.0->azureml-defaults->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 1)) (1.16.0)
# Collecting azureml-dataprep<4.1.0a,>=4.0.0a
#   Downloading azureml_dataprep-4.0.4-py3-none-any.whl (43.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting azureml-dataprep-rslex~=2.6.0dev0
#   Downloading azureml_dataprep_rslex-2.6.3-cp36-cp36m-manylinux2010_x86_64.whl (15.5 MB)
# Collecting jsonschema
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting Jinja2<3.1,>=2.10.1
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting click<8.0,>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous<2.0,>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting Werkzeug<2.0,>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.5-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 1)) (58.0.4)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (402 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Requirement already satisfied: pygments in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.43.0->azureml-defaults->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 1)) (2.11.2)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from msrest<0.7.0,>=0.5.1->azureml-core~=1.43.0->azureml-defaults->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 1)) (2021.5.30)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus<1.0.0,>=0.10.0
#   Downloading opencensus-0.10.0-py2.py3-none-any.whl (128 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.1-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.8.2-py3-none-any.whl (114 kB)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.9.1-py2.py3-none-any.whl (167 kB)
# Collecting protobuf<5.0.0dev,>=3.15.0
#   Downloading protobuf-3.19.4-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.3-py2.py3-none-any.whl (211 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.43.0->azureml-defaults->-r /azureml-environment-setup/condaenv.gs_4y_hm.requirements.txt (line 1)) (3.0.4)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.2-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (62 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.18-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.18.0-cp36-cp36m-manylinux1_x86_64.whl (117 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=627f1530edfe90473d010baa97dd34dabe25773c00b8937a15f59e0b95c6bd40
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=81cdc7f1109b2b82b84273cc818eaec4e1277e4d0491c815b16e50a8449f445e
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=76167 sha256=b0df4aa0a165e09fa910a585bdf9d35115cbf85887fca9f2cad210e781fb9681
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7681 sha256=37ac78d3a227f5e8692711d6a53f248e4a818fc46a0ff67167bbe4c385ae4583
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, typing-extensions, requests, pyasn1, zipp, rsa, pyasn1-modules, protobuf, portalocker, oauthlib, msal, immutables, cachetools, requests-oauthlib, pyrsistent, msal-extensions, isodate, importlib-metadata, googleapis-common-protos, google-auth, distro, contextvars, azure-core, attrs, pyyaml, opencensus-context, msrest, MarkupSafe, jsonschema, google-api-core, dotnetcore2, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, Werkzeug, websocket-client, tabulate, PySocks, pyopenssl, pynacl, pyarrow, psutil, opencensus, msrestazure, jmespath, Jinja2, jeepney, itsdangerous, click, bcrypt, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pkginfo, pathspec, paramiko, packaging, opencensus-ext-azure, ndg-httpsclient, knack, jsonpickle, inference-schema, humanfriendly, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.4.0 PySocks-1.7.1 SecretStorage-3.3.2 Werkzeug-1.0.1 adal-1.2.7 applicationinsights-0.11.10 argcomplete-2.0.0 attrs-21.4.0 azure-common-1.1.28 azure-core-1.24.2 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-10.0.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-10.0.0 azure-mgmt-resource-21.1.0 azure-mgmt-storage-20.0.0 azureml-core-1.43.0 azureml-dataprep-4.0.4 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.6.3 azureml-dataset-runtime-1.43.0.post2 azureml-defaults-1.43.0 azureml-inference-server-http-0.4.13 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.2 cachetools-4.2.4 cffi-1.15.1 charset-normalizer-2.0.12 click-7.1.2 cloudpickle-2.1.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-37.0.4 distro-1.7.0 docker-5.0.3 dotnetcore2-3.1.23 flask-1.0.3 fusepy-3.0.1 google-api-core-2.8.2 google-auth-2.9.1 googleapis-common-protos-1.56.3 gunicorn-20.1.0 humanfriendly-10.0 idna-3.3 immutables-0.18 importlib-metadata-4.8.3 inference-schema-1.3.0 isodate-0.6.1 itsdangerous-1.1.0 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.2.0 jsonschema-3.2.0 knack-0.9.0 msal-1.18.0 msal-extensions-0.3.1 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.0 opencensus-0.10.0 opencensus-context-0.1.2 opencensus-ext-azure-1.1.5 packaging-21.3 paramiko-2.11.0 pathspec-0.9.0 pkginfo-1.8.3 portalocker-2.5.1 protobuf-3.19.4 psutil-5.9.1 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pynacl-1.5.0 pyopenssl-22.0.0 pyrsistent-0.18.0 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.9 tabulate-0.8.10 typing-extensions-4.1.1 urllib3-1.26.9 websocket-client-1.3.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 5269bf3ea35e
#  ---> 5840d43e5d78
# Step 9/21 : ENV PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin:$PATH
#  ---> Running in 1e9093d3bc7d
# Removing intermediate container 1e9093d3bc7d
#  ---> 4587b970c32f
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> b138950d4a0d
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 2bec19450541
# Copying environment context
# Removing intermediate container 2bec19450541
#  ---> e81765fce72c
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> ec02ee03ce4f
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in 015e5c9fcc0e
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 015e5c9fcc0e
#  ---> 9b0fcc5d7e3c
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in f5d871a1644f
# Removing intermediate container f5d871a1644f
#  ---> 95c6447dc60e
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib:$LD_LIBRARY_PATH
#  ---> Running in 75274869854c
# Removing intermediate container 75274869854c
#  ---> a5233311d73f
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_0c5a9aa2def4b3c2501c1f40287a356b CONDA_PREFIX=/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in a08db2311911
# Removing intermediate container a08db2311911
#  ---> d2c6cc635964
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 068209f88fd3
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 50150867babf
# Removing intermediate container 50150867babf
#  ---> 33b9fb9daaae
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 32e6594b3438
# Removing intermediate container 32e6594b3438
#  ---> 3788fb4f3c7e
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in af4f93878d5d
# Removing intermediate container af4f93878d5d
#  ---> 15498ed27d1b
# Step 21/21 : CMD ["bash"]
#  ---> Running in 1c66ab22a9d8
# Removing intermediate container 1c66ab22a9d8
#  ---> a4884418edba
# Successfully built a4884418edba
# Successfully tagged 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06:latest
# Successfully tagged 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06:1
# 2022/07/21 22:50:05 Successfully executed container: acb_step_0
# 2022/07/21 22:50:05 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/07/21 22:50:05 Pushing image: 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06:1, attempt 1
# The push refers to repository [6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06]
# 49a3345a5210: Preparing
# bb423621aa73: Preparing
# 65196af01518: Preparing
# 0d49af81e6c8: Preparing
# 331ad73b7023: Preparing
# b10f4950b8fe: Preparing
# 2e6f5e7dc1fb: Preparing
# d30decf8fc69: Preparing
# f3ef017d0776: Preparing
# c2707b66dcbb: Preparing
# c839a7db4216: Preparing
# 0e7fa8586520: Preparing
# 5d42179dac11: Preparing
# 427fe3399545: Preparing
# bb86fa0b2bb8: Preparing
# ea56242f701b: Preparing
# 15d0cbdd54cd: Preparing
# 549ccbc27046: Preparing
# cecd54a2fd82: Preparing
# af7ed92504ae: Preparing
# b10f4950b8fe: Waiting
# 2e6f5e7dc1fb: Waiting
# 5d42179dac11: Waiting
# d30decf8fc69: Waiting
# 427fe3399545: Waiting
# f3ef017d0776: Waiting
# bb86fa0b2bb8: Waiting
# ea56242f701b: Waiting
# c2707b66dcbb: Waiting
# 15d0cbdd54cd: Waiting
# 549ccbc27046: Waiting
# c839a7db4216: Waiting
# cecd54a2fd82: Waiting
# af7ed92504ae: Waiting
# 0e7fa8586520: Waiting
# 0d49af81e6c8: Pushed
# 49a3345a5210: Pushed
# 331ad73b7023: Pushed
# bb423621aa73: Pushed
# 65196af01518: Pushed
# 2e6f5e7dc1fb: Pushed
# d30decf8fc69: Pushed
# f3ef017d0776: Pushed
# c2707b66dcbb: Pushed
# c839a7db4216: Pushed
# 0e7fa8586520: Pushed
# ea56242f701b: Pushed
# 5d42179dac11: Pushed
# 15d0cbdd54cd: Pushed
# 427fe3399545: Pushed
# 549ccbc27046: Pushed
# af7ed92504ae: Pushed
# bb86fa0b2bb8: Pushed
# cecd54a2fd82: Pushed
# b10f4950b8fe: Pushed
# 1: digest: sha256:bc79397b1802f5e724ab9b245aa197779505a3582ec8114a283d3c20f49fc331 size: 4513
# 2022/07/21 22:52:01 Successfully pushed image: 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06:1
# 2022/07/21 22:52:01 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/07/21 22:52:01 Pushing image: 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06:latest, attempt 1
# The push refers to repository [6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06]
# 49a3345a5210: Preparing
# bb423621aa73: Preparing
# 65196af01518: Preparing
# 0d49af81e6c8: Preparing
# 331ad73b7023: Preparing
# b10f4950b8fe: Preparing
# 2e6f5e7dc1fb: Preparing
# d30decf8fc69: Preparing
# f3ef017d0776: Preparing
# c2707b66dcbb: Preparing
# c839a7db4216: Preparing
# 0e7fa8586520: Preparing
# 5d42179dac11: Preparing
# 427fe3399545: Preparing
# bb86fa0b2bb8: Preparing
# ea56242f701b: Preparing
# 15d0cbdd54cd: Preparing
# 549ccbc27046: Preparing
# cecd54a2fd82: Preparing
# af7ed92504ae: Preparing
# b10f4950b8fe: Waiting
# 427fe3399545: Waiting
# 2e6f5e7dc1fb: Waiting
# d30decf8fc69: Waiting
# bb86fa0b2bb8: Waiting
# ea56242f701b: Waiting
# f3ef017d0776: Waiting
# 15d0cbdd54cd: Waiting
# 549ccbc27046: Waiting
# cecd54a2fd82: Waiting
# c2707b66dcbb: Waiting
# c839a7db4216: Waiting
# af7ed92504ae: Waiting
# 5d42179dac11: Waiting
# 0e7fa8586520: Waiting
# 0d49af81e6c8: Layer already exists
# bb423621aa73: Layer already exists
# 49a3345a5210: Layer already exists
# 331ad73b7023: Layer already exists
# f3ef017d0776: Layer already exists
# b10f4950b8fe: Layer already exists
# 65196af01518: Layer already exists
# c839a7db4216: Layer already exists
# 2e6f5e7dc1fb: Layer already exists
# 427fe3399545: Layer already exists
# c2707b66dcbb: Layer already exists
# 5d42179dac11: Layer already exists
# d30decf8fc69: Layer already exists
# 0e7fa8586520: Layer already exists
# ea56242f701b: Layer already exists
# 15d0cbdd54cd: Layer already exists
# bb86fa0b2bb8: Layer already exists
# cecd54a2fd82: Layer already exists
# af7ed92504ae: Layer already exists
# 549ccbc27046: Layer already exists
# latest: digest: sha256:bc79397b1802f5e724ab9b245aa197779505a3582ec8114a283d3c20f49fc331 size: 4513
# 2022/07/21 22:52:03 Successfully pushed image: 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io/azureml/azureml_36cdda3888712fa7886310a8bb6a8b06:latest
# 2022/07/21 22:52:03 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 153.841100)
# 2022/07/21 22:52:03 Populating digests for step ID: acb_step_0...
# 2022/07/21 22:52:04 Successfully populated digests for step ID: acb_step_0
# 2022/07/21 22:52:04 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 116.289381)
# 2022/07/21 22:52:04 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.718138)
# 2022/07/21 22:52:04 The following dependencies were found:
# 2022/07/21 22:52:04
# - image:
#     registry: 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io
#     repository: azureml/azureml_36cdda3888712fa7886310a8bb6a8b06
#     tag: latest
#     digest: sha256:bc79397b1802f5e724ab9b245aa197779505a3582ec8114a283d3c20f49fc331
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220616.v1
#     digest: sha256:2e18aafa005c25d3e0200d9dd39255ef5a30680a569cd1c3326fd65f5989db47
#   git: {}
# - image:
#     registry: 6f7c9d8fe7eb4df7b574fa52275e5ba2.azurecr.io
#     repository: azureml/azureml_36cdda3888712fa7886310a8bb6a8b06
#     tag: "1"
#     digest: sha256:bc79397b1802f5e724ab9b245aa197779505a3582ec8114a283d3c20f49fc331
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220616.v1
#     digest: sha256:2e18aafa005c25d3e0200d9dd39255ef5a30680a569cd1c3326fd65f5989db47
#   git: {}
#
#
# Run ID: ch2 was successful after 4m37s
# Streaming azureml-logs/55_azureml-execution-tvmps_77563777a360101fa750901206cec33feaf46d3b23b13c69b3445fa53da928a8_d.txt
# ========================================================================================================================
# 2022-07-21T22:57:45Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/fb15e589-1b05-4b50-bab3-86b96887b60e/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/fb15e589-1b05-4b50-bab3-86b96887b60e/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=12402 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/fb15e589-1b05-4b50-bab3-86b96887b60e/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2022-07-21T22:57:45Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/fb15e589-1b05-4b50-bab3-86b96887b60e/mounts/workspaceblobstore -- stdout/stderr:
# 2022-07-21T22:57:45Z The vmsize standard_d4as_v4 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-07-21T22:57:45Z Starting output-watcher...
# 2022-07-21T22:57:45Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2022-07-21T22:57:46Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2022-07-21T22:57:46Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 70: Pulling from azureml/curated/sidecar
# Digest: sha256:c5931fb3fb96642b435e66bd759c6595577396ede63973b46a987e6398dd8690
# Status: Image is up to date for mcr.microsoft.com/azureml/curated/sidecar:70
# mcr.microsoft.com/azureml/curated/sidecar:70
# 2022-07-21T22:57:46Z The vmsize standard_d4as_v4 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-07-21T22:57:46Z Check if container fb15e589-1b05-4b50-bab3-86b96887b60e_DataSidecar already exist exited with 0,
#
# 00da9bcc0d42153ba371048a3fdbee93e0655e8ae096caa1561203b11fa03592
# 2022-07-21T22:57:46Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2022-07-21T22:57:46Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-321f09a1f772bba346f2e8383c2ca046-b36c4729c26b6cfe-01 -sshRequired=false]
# 2022/07/21 22:57:46 Didn't get JobInfoJson from env, now read from file
# 2022/07/21 22:57:46 Suceeded read JobInfoJson from file
# 2022/07/21 22:57:46 Starting App Insight Logger for task:  containerSetup
# 2022/07/21 22:57:46 Version: 3.0.01999.0001 Branch: 20220623.1 Commit: 49a46b0
# 2022/07/21 22:57:46 Entered ContainerSetupTask - Preparing infiniband
# 2022/07/21 22:57:46 Starting infiniband setup
# 2022/07/21 22:57:46 Python Version found is Python 3.8.12
#
# 2022/07/21 22:57:46 Returning Python Version as 3.8
# 2022/07/21 22:57:46 VMSize: standard_d4as_v4, Host: ubuntu-18, Container: ubuntu-20.04
# 2022/07/21 22:57:46 VMSize: standard_d4as_v4, Host: ubuntu-18, Container: ubuntu-20.04
# 2022-07-21T22:57:46Z VMSize: standard_d4as_v4, Host: ubuntu-18, Container: ubuntu-20.04
# 2022/07/21 22:57:46 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2022/07/21 22:57:46 Not setting up Infiniband in Container
# 2022/07/21 22:57:46 Not setting up Infiniband in Container
# 2022-07-21T22:57:46Z Not setting up Infiniband in Container
# 2022/07/21 22:57:46 Python Version found is Python 3.8.12
#
# 2022/07/21 22:57:46 Returning Python Version as 3.8
# 2022/07/21 22:57:46 sshd inside container not required for job, skipping setup.
# 2022/07/21 22:57:46 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2022/07/21 22:57:46 App Insight Client has already been closed
# 2022/07/21 22:57:46 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2022-07-21T22:57:46Z Starting docker container succeeded.
# 2022-07-21T22:57:46Z The vmsize standard_d4as_v4 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-07-21T22:57:54Z The vmsize standard_d4as_v4 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-07-21T22:57:54Z The vmsize standard_d4as_v4 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-07-21T22:57:54Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2022-07-21T22:57:54Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# ...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:26.941863] job release stage : start importing azureml.history._tracking in run_history_release.
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:26.943327] job release stage : copy_batchai_cached_logs starting...[2022-07-21T22:59:26.945562] job release stage : execute_job_release starting...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing:
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:26.950824] job release stage : copy_batchai_cached_logs completed...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:26.951583] Entering context manager injector.
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:26.955342] job release stage : upload_datastore completed...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.028273] job release stage : send_run_telemetry starting...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.054058] get vm size and vm region successfully.
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.067824] get compute meta data successfully.
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.146514] job release stage : execute_job_release completed...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.167325] post artifact meta request successfully.
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.200779] upload compute record artifact successfully.
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.200832] job release stage : send_run_telemetry completed...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.201031] Running in AzureML-Sidecar, starting to exit user context managers...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.201087] Running Sidecar release cmd...
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.208567] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:27.221] Enter __exit__ of DatasetContextManager
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [[[Context Manager output has been redacted.]]]
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:28.320210] Ran Sidecar release cmd.
# >>>   2022/07/21 22:59:28 runSpecialJobTask->SideCar + : postprocessing: [2022-07-21T22:59:28.320284] Job release is complete
# >>>   2022/07/21 22:59:28 DockerSideCarContainerLogs:
# >>>   [2022-07-21T22:59:09.829532] INFO azureml.sidecar.sidecar: Received task: start. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284
# >>>   [2022-07-21T22:59:09.841523] INFO azureml.sidecar.sidecar: Started TaskServer. Address: 127.0.0.1, Port: 54053
# >>>   [2022-07-21T22:59:11.631018] INFO azureml.sidecar.task.enter_contexts: Constructing Context Managers
# >>>   [2022-07-21T22:59:11.766] Initialize DatasetContextManager.
# >>>   [2022-07-21T22:59:11.767728] INFO azureml.sidecar.task.enter_contexts: Entering Context Managers
# >>>   [2022-07-21T22:59:11.768178] INFO azureml.sidecar.context_manager_wrapper: Entering context: Dataset
# >>>   fuse: warning: library too old, some operations may not not work
# >>>   [2022-07-21T22:59:14.480959] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# >>>   [2022-07-21T22:59:14.482394] INFO azureml.sidecar.task.enter_contexts: New or updated environment variable 'AZUREML_DATAREFERENCE_input_3f359a15' with value '/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/input_3f359a15_eca37e59-ec23-44e6-b35b-e5c2b125224d'.
# >>>   [2022-07-21T22:59:14.488128] INFO azureml.sidecar.task.enter_contexts: New or updated environment variable 'input_3f359a15' with value '/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/input_3f359a15_eca37e59-ec23-44e6-b35b-e5c2b125224d'.
# >>>   [2022-07-21T22:59:14.488426] INFO azureml.sidecar.task.enter_contexts: New or updated environment variable 'INPUT_3F359A15' with value '/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/input_3f359a15_eca37e59-ec23-44e6-b35b-e5c2b125224d'.
# >>>   [2022-07-21T22:59:14.488610] INFO azureml.sidecar.task.enter_contexts: New or updated environment variable 'AZURE_ML_INPUT_input_3f359a15' with value '/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/input_3f359a15_eca37e59-ec23-44e6-b35b-e5c2b125224d'.
# >>>   [2022-07-21T22:59:14.488813] INFO azureml.sidecar.task.enter_contexts: New or updated environment variable 'AZUREML_SIDECAR_PATHS_TO_BIND' with value '["/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/input_3f359a15_eca37e59-ec23-44e6-b35b-e5c2b125224d:/mnt/batch/tasks/shared/LS_root/jobs/al'.
# >>>   [2022-07-21T22:59:27.215021] INFO azureml.sidecar.task.exit_contexts: Exiting Context Managers
# >>>   [2022-07-21T22:59:27.215771] INFO azureml.sidecar.context_manager_wrapper: Exiting context: Dataset
# >>>   [2022-07-21T22:59:28.222405] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# >>>
# >>>   2022/07/21 22:59:28 DockerSideCarContainerLogs End
# >>>   2022/07/21 22:59:28 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>   2022/07/21 22:59:28 App Insight Client has already been closed
# >>>   2022/07/21 22:59:28 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>
# 2022-07-21T22:59:28Z Executing 'Job environment clean-up' on 10.0.0.4
# 2022-07-21T22:59:29Z Removing container 4db31ac8-1657-49c7-9e7b-a085cdbda284 exited with 0, 4db31ac8-1657-49c7-9e7b-a085cdbda284
#
#
# 2022-07-21T22:59:29Z Removing container 4db31ac8-1657-49c7-9e7b-a085cdbda284_DataSidecar exited with 0, 4db31ac8-1657-49c7-9e7b-a085cdbda284_DataSidecar
# Streaming azureml-logs/75_job_post-tvmps_77563777a360101fa750901206cec33feaf46d3b23b13c69b3445fa53da928a8_d.txt
# ===============================================================================================================
# [2022-07-21T22:59:26.293535] Entering job release
# [2022-07-21T22:59:26.940684] Starting job release
# [2022-07-21T22:59:26.941058] Logging experiment finalizing status in history service.
# [2022-07-21T22:59:26.941209] job release stage : upload_datastore starting...Starting the daemon thread to refresh tokens in background for process with pid = 220
#
# [2022-07-21T22:59:26.941863] job release stage : start importing azureml.history._tracking in run_history_release.
# [2022-07-21T22:59:26.943327] job release stage : copy_batchai_cached_logs starting...[2022-07-21T22:59:26.945562] job release stage : execute_job_release starting...
#
# [2022-07-21T22:59:26.950824] job release stage : copy_batchai_cached_logs completed...
# [2022-07-21T22:59:26.951583] Entering context manager injector.
# [2022-07-21T22:59:26.955342] job release stage : upload_datastore completed...
# [2022-07-21T22:59:27.028273] job release stage : send_run_telemetry starting...
# [2022-07-21T22:59:27.054058] get vm size and vm region successfully.
# [2022-07-21T22:59:27.067824] get compute meta data successfully.
# [2022-07-21T22:59:27.146514] job release stage : execute_job_release completed...
# [2022-07-21T22:59:27.167325] post artifact meta request successfully.
# [2022-07-21T22:59:27.200779] upload compute record artifact successfully.
# [2022-07-21T22:59:27.200832] job release stage : send_run_telemetry completed...
# [2022-07-21T22:59:27.201031] Running in AzureML-Sidecar, starting to exit user context managers...
# [2022-07-21T22:59:27.201087] Running Sidecar release cmd...
# [2022-07-21T22:59:27.208567] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284
# [2022-07-21T22:59:27.221] Enter __exit__ of DatasetContextManager
# [2022-07-21T22:59:27.221] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/input_3f359a15_eca37e59-ec23-44e6-b35b-e5c2b125224d.
# [2022-07-21T22:59:28.221] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/ali_workspace_student/azureml/4db31ac8-1657-49c7-9e7b-a085cdbda284/wd/input_3f359a15_eca37e59-ec23-44e6-b35b-e5c2b125224d.
# [2022-07-21T22:59:28.222] Exit __exit__ of DatasetContextManager
# [2022-07-21T22:59:28.222026] Removing absolute paths from host...
# [2022-07-21T22:59:28.222405] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2022-07-21T22:59:28.320210] Ran Sidecar release cmd.
# [2022-07-21T22:59:28.320284] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '4db31ac8-1657-49c7-9e7b-a085cdbda284', 'target': 'anabavib1', 'status': 'Completed', 'startTimeUtc': '2022-07-21T22:59:05.610383Z', 'endTimeUtc': '2022-07-21T22:59:35.971851Z', 'services': {}, 'properties': {'ContentSnapshotId': '4b6e594c-4ff4-47f2-925c-fe457003b3c6', 'StepType': 'PythonScriptStep', 'azureml.moduleid': 'ed859403-2df6-4752-a5b8-41e724209469', 'azureml.moduleName': 'Train and Register Model', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'a380ff1b', 'azureml.pipelinerunid': '28e74074-91be-47db-9db1-8be0cd9b2e83', 'azureml.pipeline': '28e74074-91be-47db-9db1-8be0cd9b2e83', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'eca37e59-ec23-44e6-b35b-e5c2b125224d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_3f359a15', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-data', 'DatasetConsumptionConfig:input_3f359a15'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'anabavib1', 'dataReferences': {}, 'data': {'input_3f359a15': {'dataLocation': {'dataset': {'id': 'eca37e59-ec23-44e6-b35b-e5c2b125224d', 'name': None, 'version': None}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_3f359a15', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': '2', 'assetId': 'azureml://locations/eastus2/workspaces/6f7c9d8f-e7eb-4df7-b574-fa52275e5ba2/environments/experiment_env/versions/2', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'experiment_env', 'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220616.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '28e74074-91be-47db-9db1-8be0cd9b2e83', 'status': 'Completed', 'startTimeUtc': '2022-07-21T22:47:22.537463Z', 'endTimeUtc': '2022-07-21T22:59:37.010338Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://aliworkspacest6241059068.blob.core.windows.net/azureml/ExperimentRun/dcid.28e74074-91be-47db-9db1-8be0cd9b2e83/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=mOFbR6KT5vpPG3j5F0zQdpxmot8nXDG0cpWJampEfFg%3D&skoid=89b037e1-e81a-4bae-a716-a38886961045&sktid=41f88ecb-ca63-404d-97dd-ab0a169fd138&skt=2022-07-21T21%3A31%3A59Z&ske=2022-07-23T05%3A41%3A59Z&sks=b&skv=2019-07-07&st=2022-07-21T22%3A48%3A09Z&se=2022-07-22T06%3A58%3A09Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://aliworkspacest6241059068.blob.core.windows.net/azureml/ExperimentRun/dcid.28e74074-91be-47db-9db1-8be0cd9b2e83/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=ZkjtJgDo%2BVBKLO53%2BKRtKMbecqBGZYh7KjN7zjsZ1Qc%3D&skoid=89b037e1-e81a-4bae-a716-a38886961045&sktid=41f88ecb-ca63-404d-97dd-ab0a169fd138&skt=2022-07-21T21%3A31%3A59Z&ske=2022-07-23T05%3A41%3A59Z&sks=b&skv=2019-07-07&st=2022-07-21T22%3A48%3A09Z&se=2022-07-22T06%3A58%3A09Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://aliworkspacest6241059068.blob.core.windows.net/azureml/ExperimentRun/dcid.28e74074-91be-47db-9db1-8be0cd9b2e83/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=0YbNAxZjmzuvFKDAyiiYlDzs8yNIQ15DouCzjuBtYS4%3D&skoid=89b037e1-e81a-4bae-a716-a38886961045&sktid=41f88ecb-ca63-404d-97dd-ab0a169fd138&skt=2022-07-21T21%3A31%3A59Z&ske=2022-07-23T05%3A41%3A59Z&sks=b&skv=2019-07-07&st=2022-07-21T22%3A48%3A09Z&se=2022-07-22T06%3A58%3A09Z&sp=r'}, 'submittedBy': 'Miralireza Nabavi Bavil'}
# 'Finished'

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8926666666666667
# 	 AUC : 0.8791133887258072
# 	 ROC : aml://artifactId/ExperimentRun/dcid.4db31ac8-1657-49c7-9e7b-a085cdbda284/ROC_1658444358.png
# Prepare Data :
# 	 raw_rows : 10000
# 	 processed_rows : 10000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 14
# 	 Training context : Pipeline
# 	 AUC : 0.8728767600378128
# 	 Accuracy : 0.8863333333333333
#
#
# diabetes_model version: 13
# 	 Training context : Compute cluster
# 	 AUC : 0.8755958007861088
# 	 Accuracy : 0.888
#
#
# diabetes_model version: 12
# 	 Training context : File dataset
# 	 AUC : 0.8483198169063138
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 11
# 	 Training context : Tabular dataset
# 	 AUC : 0.8484024080800039
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 10
# 	 Training context : File dataset
# 	 AUC : 0.8468519356081545
# 	 Accuracy : 0.7788888888888889
#
#
# diabetes_model version: 9
# 	 Training context : Tabular dataset
# 	 AUC : 0.8569287675378097
# 	 Accuracy : 0.79
#
#
# diabetes_model version: 8
# 	 Training context : Parameterized script
# 	 AUC : 0.8483198169063138
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 7
# 	 Training context : Parameterized script
# 	 AUC : 0.8483198169063138
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 6
# 	 Training context : Script
# 	 AUC : 0.8483899696502313
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 5
# 	 Training context : Parameterized script
# 	 AUC : 0.8483198169063138
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 4
# 	 Training context : Script
# 	 AUC : 0.8483899696502313
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 3
# 	 Training context : Script
# 	 AUC : 0.8483899696502313
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8483586248072043
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8483979302452859
# 	 Accuracy : 0.7736666666666666

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: cac605a7-5e50-4f91-bca9-1b59a8756738,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/1b822ee6-a558-4a5d-8ad7-7af385162a03/resourceGroups/ali_student_workspace/providers/Microsoft.MachineLearningServices/workspaces/ali_workspace_student/PipelineRuns/PipelineSubmit/cac605a7-5e50-4f91-bca9-1b59a8756738)
